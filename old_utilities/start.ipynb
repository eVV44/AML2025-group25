# %%
## -- IMPORTS --
import torch
import torch.nn as nn
import numpy as np
import os
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from torchvision import transforms
from sklearn.model_selection import train_test_split
from dataset_util import BirdDataset
from torch.utils.data import DataLoader
from dataset_util import train_val_loaders, train_val_loaders_with_attributes
from models import create_model

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import zipfile
import os

file_name = "train_images.zip"  # change to your filename

with zipfile.ZipFile(file_name, 'r') as zip_ref:
    zip_ref.extractall()

# %%
# load and clean paths
train_df = pd.read_csv("train_images.csv")

train_df["image_path"] = train_df["image_path"].str.lstrip("/")
train_df["image_path"] = train_df["image_path"].apply(lambda x: "train_images/" + x)
train_df["label_idx"] = train_df["label"] - 1

train_df.head()
# Out:
#                         image_path  label  label_idx
# 0  train_images/train_images/1.jpg      1          0
# 1  train_images/train_images/2.jpg      1          0
# 2  train_images/train_images/3.jpg      1          0
# 3  train_images/train_images/4.jpg      1          0
# 4  train_images/train_images/5.jpg      1          0

# %%
attributes = np.load("attributes.npy", allow_pickle=True)

# %%
# class distribution
num_classes = train_df["label_idx"].nunique()
print("Number of images:", len(train_df))
print("Number of classes:", num_classes)

train_df["label"].value_counts().head()
# Out:
# Number of images: 3926
# Number of classes: 200
# label
# 1     35
# 2     35
# 4     35
# 9     34
# 10    34
# Name: count, dtype: int64

# %%
# # see one bird
# row0 = train_df.iloc[0]
# img = Image.open(row0["image_path"]).convert("RGB")
# plt.imshow(img)
# plt.title(f"Label: {row0['label']} (idx {row0['label_idx']})")
# plt.axis("off")
# plt.show()

# %%
batch_size = 64

train_loader, val_loader, train_df_split, val_df_split = train_val_loaders(
    train_df,
    img_size=(224, 224),
    batch_size=batch_size,
    val_size=0.2,
    random_state=42,
    num_workers=2,
    use_imagenet_norm=True,
    augment=True)

# for the multi task model:
train_loader, val_loader, train_df_split, val_df_split = train_val_loaders_with_attributes(
    train_df,
    attributes=attributes,
    img_size=(224, 224),
    batch_size=batch_size,
    val_size=0.2,
    random_state=42,
    num_workers=2,
    use_imagenet_norm=True,
    augment=True)

# %% [markdown]
# ### Pipeline start

# %%
# Hyperparameters (placeholders)
embedding_dim = 128
lr = 1e-3
epochs = 25

# %%
# Model (placeholders)
from embedder_models import BirdEmbeddingModel
from multi_task_models import BirdMultiTaskModel

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# model_name = "bird_embedding"
model_name = "multi_task_cnn"

model = create_model(
    model_name=model_name,
    n_classes=200,
    n_attributes=attributes.shape[1],
    feature_dim=256)

model = model.to(device)
print("Using model:", model_name, "on", device)
# Out:
# Using model: multi_task_cnn on cuda

# %%
# # Training
# for epoch in range(epochs):
#     model.train()

#     running_loss = 0.0
#     running_correct = 0
#     running_total = 0

#     for images, labels in train_loader:
#         images = images.to(device)
#         labels = labels.to(device)

#         optimizer.zero_grad()

#         # forward pass
#         logits = model(images)
#         loss = criterion(logits, labels)

#         # backward pass
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item() * images.size(0)
#         preds = logits.argmax(dim=1)
#         running_correct += (preds == labels).sum().item()
#         running_total += labels.size(0)

#     epoch_loss = running_loss / running_total
#     epoch_acc = running_correct / running_total

#     print(f"Epoch [{epoch+1}/{epochs}] - Train Loss: {epoch_loss:.4f} - Train Acc: {epoch_acc:.4f}")

#     # continue code...

# %%
# Hyperparameters for multi-task
lr = 1e-3
epochs = 80
lambda_attr = 1.0
best_val_acc = 0.0

train_losses = []
val_losses = []
train_class_losses = []
val_class_losses = []
train_attr_losses = []
val_attr_losses = []
train_accs = []
val_accs = []

criterion_class = nn.CrossEntropyLoss()
criterion_attr  = nn.BCEWithLogitsLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# TRAINING
for epoch in range(epochs):
    model.train()

    running_loss = 0.0
    running_class_loss = 0.0
    running_attr_loss = 0.0
    running_correct = 0
    running_total = 0

    for images, labels, attr_vecs in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        attr_vecs = attr_vecs.to(device)

        optimizer.zero_grad()

        # forward pass: returns two things
        class_logits, attr_logits = model(images)

        # main task: class prediction
        loss_class = criterion_class(class_logits, labels)

        # auxiliary task: attribute prediction
        loss_attr = criterion_attr(attr_logits, attr_vecs)

        # total loss
        loss = loss_class + lambda_attr * loss_attr

        # backward pass
        loss.backward()
        optimizer.step()

        # stats
        running_loss += loss.item() * images.size(0)
        running_class_loss += loss_class.item() * images.size(0)
        running_attr_loss += loss_attr.item() * images.size(0)

        preds = class_logits.argmax(dim=1)
        running_correct += (preds == labels).sum().item()
        running_total += labels.size(0)

    epoch_loss = running_loss / running_total
    epoch_class_loss = running_class_loss / running_total
    epoch_attr_loss = running_attr_loss / running_total
    epoch_acc = running_correct / running_total

# VALIDATION
    model.eval()

    val_loss = 0.0
    val_class_loss = 0.0
    val_attr_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for images, labels, attr_vecs in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            attr_vecs = attr_vecs.to(device)

            class_logits, attr_logits = model(images)

            loss_class = criterion_class(class_logits, labels)
            loss_attr  = criterion_attr(attr_logits, attr_vecs)
            loss = loss_class + lambda_attr * loss_attr

            val_loss += loss.item() * images.size(0)
            val_class_loss += loss_class.item() * images.size(0)
            val_attr_loss += loss_attr.item() * images.size(0)

            preds = class_logits.argmax(dim=1)
            val_correct += (preds == labels).sum().item()
            val_total += labels.size(0)

    epoch_val_loss = val_loss / val_total
    epoch_val_class_loss = val_class_loss / val_total
    epoch_val_attr_loss = val_attr_loss / val_total
    epoch_val_acc = val_correct / val_total

    # save best model
    if epoch_val_acc > best_val_acc:
        best_val_acc = epoch_val_acc
        torch.save(model.state_dict(), "best_multitask_model.pth")

    train_losses.append(epoch_loss)
    val_losses.append(epoch_val_loss)
    train_class_losses.append(epoch_class_loss)
    val_class_losses.append(epoch_val_class_loss)
    train_attr_losses.append(epoch_attr_loss)
    val_attr_losses.append(epoch_val_attr_loss)
    train_accs.append(epoch_acc)
    val_accs.append(epoch_val_acc)

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"- Train Loss: {epoch_loss:.4f} (cls {epoch_class_loss:.4f}, attr {epoch_attr_loss:.4f}) "
        f"- Train Acc: {epoch_acc:.4f} "
        f"- Val Loss: {epoch_val_loss:.4f} (cls {epoch_val_class_loss:.4f}, attr {epoch_val_attr_loss:.4f}) "
        f"- Val Acc: {epoch_val_acc:.4f}")

print(f"Best Val Acc: {best_val_acc:.4f}")
# Out:
# Epoch [1/80] - Train Loss: 5.6363 (cls 5.3283, attr 0.3080) - Train Acc: 0.0073 - Val Loss: 5.3899 (cls 5.2107, attr 0.1792) - Val Acc: 0.0051
# Epoch [2/80] - Train Loss: 5.3827 (cls 5.2469, attr 0.1359) - Train Acc: 0.0057 - Val Loss: 5.3117 (cls 5.1836, attr 0.1281) - Val Acc: 0.0153
# Epoch [3/80] - Train Loss: 5.3220 (cls 5.1974, attr 0.1246) - Train Acc: 0.0080 - Val Loss: 5.2149 (cls 5.0961, attr 0.1187) - Val Acc: 0.0191
# Epoch [4/80] - Train Loss: 5.2365 (cls 5.1159, attr 0.1206) - Train Acc: 0.0156 - Val Loss: 5.1986 (cls 5.0786, attr 0.1201) - Val Acc: 0.0153
# Epoch [5/80] - Train Loss: 5.1923 (cls 5.0741, attr 0.1183) - Train Acc: 0.0115 - Val Loss: 5.1406 (cls 5.0274, attr 0.1132) - Val Acc: 0.0191
# Epoch [6/80] - Train Loss: 5.1628 (cls 5.0453, attr 0.1175) - Train Acc: 0.0131 - Val Loss: 5.1236 (cls 5.0068, attr 0.1169) - Val Acc: 0.0178
# Epoch [7/80] - Train Loss: 5.1340 (cls 5.0171, attr 0.1169) - Train Acc: 0.0159 - Val Loss: 5.1120 (cls 4.9972, attr 0.1147) - Val Acc: 0.0165
# Epoch [8/80] - Train Loss: 5.1229 (cls 5.0035, attr 0.1194) - Train Acc: 0.0150 - Val Loss: 5.0917 (cls 4.9740, attr 0.1178) - Val Acc: 0.0242
# Epoch [9/80] - Train Loss: 5.1029 (cls 4.9842, attr 0.1187) - Train Acc: 0.0140 - Val Loss: 5.0824 (cls 4.9672, attr 0.1152) - Val Acc: 0.0267
# Epoch [10/80] - Train Loss: 5.0823 (cls 4.9656, attr 0.1167) - Train Acc: 0.0175 - Val Loss: 5.0780 (cls 4.9609, attr 0.1171) - Val Acc: 0.0280
# Epoch [11/80] - Train Loss: 5.0589 (cls 4.9410, attr 0.1179) - Train Acc: 0.0210 - Val Loss: 5.0538 (cls 4.9355, attr 0.1183) - Val Acc: 0.0229
# Epoch [12/80] - Train Loss: 5.0453 (cls 4.9259, attr 0.1194) - Train Acc: 0.0156 - Val Loss: 5.0285 (cls 4.9102, attr 0.1184) - Val Acc: 0.0318
# Epoch [13/80] - Train Loss: 5.0140 (cls 4.8952, attr 0.1188) - Train Acc: 0.0223 - Val Loss: 5.0309 (cls 4.9148, attr 0.1161) - Val Acc: 0.0254
# Epoch [14/80] - Train Loss: 5.0004 (cls 4.8824, attr 0.1181) - Train Acc: 0.0232 - Val Loss: 5.0341 (cls 4.9121, attr 0.1221) - Val Acc: 0.0344
# Epoch [15/80] - Train Loss: 5.0017 (cls 4.8777, attr 0.1240) - Train Acc: 0.0271 - Val Loss: 4.9795 (cls 4.8619, attr 0.1176) - Val Acc: 0.0420
# Epoch [16/80] - Train Loss: 4.9407 (cls 4.8221, attr 0.1185) - Train Acc: 0.0290 - Val Loss: 4.9758 (cls 4.8562, attr 0.1196) - Val Acc: 0.0318
# Epoch [17/80] - Train Loss: 4.9228 (cls 4.8039, attr 0.1189) - Train Acc: 0.0258 - Val Loss: 4.9487 (cls 4.8303, attr 0.1184) - Val Acc: 0.0331
# Epoch [18/80] - Train Loss: 4.9028 (cls 4.7826, attr 0.1202) - Train Acc: 0.0248 - Val Loss: 4.9686 (cls 4.8488, attr 0.1197) - Val Acc: 0.0382
# Epoch [19/80] - Train Loss: 4.9034 (cls 4.7827, attr 0.1207) - Train Acc: 0.0277 - Val Loss: 4.9525 (cls 4.8300, attr 0.1225) - Val Acc: 0.0331
# Epoch [20/80] - Train Loss: 4.8781 (cls 4.7580, attr 0.1201) - Train Acc: 0.0328 - Val Loss: 4.9138 (cls 4.7951, attr 0.1187) - Val Acc: 0.0356
# Epoch [21/80] - Train Loss: 4.8402 (cls 4.7204, attr 0.1198) - Train Acc: 0.0287 - Val Loss: 4.9000 (cls 4.7801, attr 0.1199) - Val Acc: 0.0344
# Epoch [22/80] - Train Loss: 4.8210 (cls 4.7011, attr 0.1199) - Train Acc: 0.0382 - Val Loss: 4.8924 (cls 4.7734, attr 0.1190) - Val Acc: 0.0331
# Epoch [23/80] - Train Loss: 4.8073 (cls 4.6877, attr 0.1195) - Train Acc: 0.0357 - Val Loss: 4.8750 (cls 4.7557, attr 0.1194) - Val Acc: 0.0369
# Epoch [24/80] - Train Loss: 4.7821 (cls 4.6623, attr 0.1198) - Train Acc: 0.0389 - Val Loss: 4.9238 (cls 4.8043, attr 0.1195) - Val Acc: 0.0382
# Epoch [25/80] - Train Loss: 4.7718 (cls 4.6523, attr 0.1195) - Train Acc: 0.0382 - Val Loss: 4.8624 (cls 4.7436, attr 0.1187) - Val Acc: 0.0420
# Epoch [26/80] - Train Loss: 4.7590 (cls 4.6408, attr 0.1182) - Train Acc: 0.0408 - Val Loss: 4.8675 (cls 4.7471, attr 0.1204) - Val Acc: 0.0382
# Epoch [27/80] - Train Loss: 4.7292 (cls 4.6102, attr 0.1190) - Train Acc: 0.0446 - Val Loss: 4.8636 (cls 4.7441, attr 0.1195) - Val Acc: 0.0420
# Epoch [28/80] - Train Loss: 4.7077 (cls 4.5893, attr 0.1184) - Train Acc: 0.0462 - Val Loss: 4.8240 (cls 4.7053, attr 0.1187) - Val Acc: 0.0534
# Epoch [29/80] - Train Loss: 4.6678 (cls 4.5499, attr 0.1179) - Train Acc: 0.0510 - Val Loss: 4.8339 (cls 4.7131, attr 0.1209) - Val Acc: 0.0483
# Epoch [30/80] - Train Loss: 4.6553 (cls 4.5359, attr 0.1194) - Train Acc: 0.0510 - Val Loss: 4.8649 (cls 4.7425, attr 0.1224) - Val Acc: 0.0433
# Epoch [31/80] - Train Loss: 4.6547 (cls 4.5361, attr 0.1186) - Train Acc: 0.0443 - Val Loss: 4.8164 (cls 4.6969, attr 0.1196) - Val Acc: 0.0445
# Epoch [32/80] - Train Loss: 4.5957 (cls 4.4781, attr 0.1176) - Train Acc: 0.0513 - Val Loss: 4.8337 (cls 4.7170, attr 0.1167) - Val Acc: 0.0573
# Epoch [33/80] - Train Loss: 4.5746 (cls 4.4572, attr 0.1174) - Train Acc: 0.0586 - Val Loss: 4.7582 (cls 4.6411, attr 0.1171) - Val Acc: 0.0623
# Epoch [34/80] - Train Loss: 4.5374 (cls 4.4202, attr 0.1172) - Train Acc: 0.0599 - Val Loss: 4.7684 (cls 4.6508, attr 0.1176) - Val Acc: 0.0649
# Epoch [35/80] - Train Loss: 4.5156 (cls 4.3984, attr 0.1172) - Train Acc: 0.0608 - Val Loss: 4.7501 (cls 4.6334, attr 0.1167) - Val Acc: 0.0712
# Epoch [36/80] - Train Loss: 4.4719 (cls 4.3542, attr 0.1176) - Train Acc: 0.0701 - Val Loss: 4.7297 (cls 4.6111, attr 0.1186) - Val Acc: 0.0789
# Epoch [37/80] - Train Loss: 4.4524 (cls 4.3338, attr 0.1186) - Train Acc: 0.0701 - Val Loss: 4.7298 (cls 4.6127, attr 0.1171) - Val Acc: 0.0674
# Epoch [38/80] - Train Loss: 4.4664 (cls 4.3479, attr 0.1185) - Train Acc: 0.0732 - Val Loss: 4.7074 (cls 4.5887, attr 0.1186) - Val Acc: 0.0789
# Epoch [39/80] - Train Loss: 4.3974 (cls 4.2794, attr 0.1179) - Train Acc: 0.0732 - Val Loss: 4.7174 (cls 4.6011, attr 0.1163) - Val Acc: 0.0802
# Epoch [40/80] - Train Loss: 4.3674 (cls 4.2504, attr 0.1170) - Train Acc: 0.0812 - Val Loss: 4.6961 (cls 4.5794, attr 0.1168) - Val Acc: 0.0725
# Epoch [41/80] - Train Loss: 4.3530 (cls 4.2339, attr 0.1191) - Train Acc: 0.0710 - Val Loss: 4.6521 (cls 4.5341, attr 0.1181) - Val Acc: 0.0776
# Epoch [42/80] - Train Loss: 4.3128 (cls 4.1948, attr 0.1180) - Train Acc: 0.0927 - Val Loss: 4.6735 (cls 4.5557, attr 0.1177) - Val Acc: 0.0827
# Epoch [43/80] - Train Loss: 4.2370 (cls 4.1187, attr 0.1183) - Train Acc: 0.0889 - Val Loss: 4.6109 (cls 4.4897, attr 0.1212) - Val Acc: 0.0929
# Epoch [44/80] - Train Loss: 4.2275 (cls 4.1100, attr 0.1174) - Train Acc: 0.1000 - Val Loss: 4.6091 (cls 4.4919, attr 0.1173) - Val Acc: 0.0814
# Epoch [45/80] - Train Loss: 4.1702 (cls 4.0524, attr 0.1178) - Train Acc: 0.0968 - Val Loss: 4.6725 (cls 4.5513, attr 0.1212) - Val Acc: 0.0700
# Epoch [46/80] - Train Loss: 4.1858 (cls 4.0678, attr 0.1180) - Train Acc: 0.1003 - Val Loss: 4.5678 (cls 4.4509, attr 0.1168) - Val Acc: 0.0865
# Epoch [47/80] - Train Loss: 4.1209 (cls 4.0032, attr 0.1177) - Train Acc: 0.0984 - Val Loss: 4.5265 (cls 4.4097, attr 0.1168) - Val Acc: 0.0878
# Epoch [48/80] - Train Loss: 4.0798 (cls 3.9614, attr 0.1184) - Train Acc: 0.0994 - Val Loss: 4.5809 (cls 4.4634, attr 0.1176) - Val Acc: 0.0954
# Epoch [49/80] - Train Loss: 4.1216 (cls 4.0033, attr 0.1183) - Train Acc: 0.1038 - Val Loss: 4.5838 (cls 4.4679, attr 0.1159) - Val Acc: 0.0980
# Epoch [50/80] - Train Loss: 4.0126 (cls 3.8951, attr 0.1175) - Train Acc: 0.1153 - Val Loss: 4.5884 (cls 4.4716, attr 0.1168) - Val Acc: 0.0916
# Epoch [51/80] - Train Loss: 4.0038 (cls 3.8860, attr 0.1178) - Train Acc: 0.1073 - Val Loss: 4.6145 (cls 4.4973, attr 0.1172) - Val Acc: 0.1005
# Epoch [52/80] - Train Loss: 3.9466 (cls 3.8290, attr 0.1177) - Train Acc: 0.1131 - Val Loss: 4.5316 (cls 4.4134, attr 0.1181) - Val Acc: 0.1107
# Epoch [53/80] - Train Loss: 3.9002 (cls 3.7827, attr 0.1175) - Train Acc: 0.1166 - Val Loss: 4.4808 (cls 4.3637, attr 0.1171) - Val Acc: 0.1018
# Epoch [54/80] - Train Loss: 3.8853 (cls 3.7679, attr 0.1175) - Train Acc: 0.1309 - Val Loss: 4.4770 (cls 4.3610, attr 0.1160) - Val Acc: 0.1132
# Epoch [55/80] - Train Loss: 3.7993 (cls 3.6822, attr 0.1170) - Train Acc: 0.1344 - Val Loss: 4.4870 (cls 4.3721, attr 0.1149) - Val Acc: 0.1031
# Epoch [56/80] - Train Loss: 3.7686 (cls 3.6519, attr 0.1167) - Train Acc: 0.1475 - Val Loss: 4.4749 (cls 4.3585, attr 0.1164) - Val Acc: 0.1005
# Epoch [57/80] - Train Loss: 3.7454 (cls 3.6284, attr 0.1170) - Train Acc: 0.1369 - Val Loss: 4.4281 (cls 4.3134, attr 0.1146) - Val Acc: 0.1132
# Epoch [58/80] - Train Loss: 3.7487 (cls 3.6321, attr 0.1166) - Train Acc: 0.1424 - Val Loss: 4.5047 (cls 4.3890, attr 0.1156) - Val Acc: 0.1018
# Epoch [59/80] - Train Loss: 3.6991 (cls 3.5831, attr 0.1160) - Train Acc: 0.1446 - Val Loss: 4.5262 (cls 4.4115, attr 0.1148) - Val Acc: 0.1081
# Epoch [60/80] - Train Loss: 3.6250 (cls 3.5085, attr 0.1165) - Train Acc: 0.1694 - Val Loss: 4.5885 (cls 4.4721, attr 0.1164) - Val Acc: 0.1132
# Epoch [61/80] - Train Loss: 3.6266 (cls 3.5101, attr 0.1166) - Train Acc: 0.1611 - Val Loss: 4.4393 (cls 4.3237, attr 0.1156) - Val Acc: 0.1196
# Epoch [62/80] - Train Loss: 3.5818 (cls 3.4652, attr 0.1166) - Train Acc: 0.1608 - Val Loss: 4.5104 (cls 4.3952, attr 0.1152) - Val Acc: 0.1272
# Epoch [63/80] - Train Loss: 3.5122 (cls 3.3962, attr 0.1160) - Train Acc: 0.1653 - Val Loss: 4.4796 (cls 4.3638, attr 0.1158) - Val Acc: 0.1234
# Epoch [64/80] - Train Loss: 3.5131 (cls 3.3968, attr 0.1163) - Train Acc: 0.1764 - Val Loss: 4.4654 (cls 4.3492, attr 0.1162) - Val Acc: 0.1170
# Epoch [65/80] - Train Loss: 3.4552 (cls 3.3395, attr 0.1158) - Train Acc: 0.1895 - Val Loss: 4.4823 (cls 4.3678, attr 0.1146) - Val Acc: 0.1158
# Epoch [66/80] - Train Loss: 3.4217 (cls 3.3065, attr 0.1153) - Train Acc: 0.1854 - Val Loss: 4.4730 (cls 4.3589, attr 0.1141) - Val Acc: 0.1158
# Epoch [67/80] - Train Loss: 3.4077 (cls 3.2921, attr 0.1157) - Train Acc: 0.1927 - Val Loss: 4.5884 (cls 4.4737, attr 0.1147) - Val Acc: 0.1196
# Epoch [68/80] - Train Loss: 3.3615 (cls 3.2461, attr 0.1154) - Train Acc: 0.2006 - Val Loss: 4.5992 (cls 4.4841, attr 0.1151) - Val Acc: 0.1094
# Epoch [69/80] - Train Loss: 3.3622 (cls 3.2466, attr 0.1156) - Train Acc: 0.1968 - Val Loss: 4.5675 (cls 4.4531, attr 0.1144) - Val Acc: 0.1196
# Epoch [70/80] - Train Loss: 3.3280 (cls 3.2125, attr 0.1155) - Train Acc: 0.2054 - Val Loss: 4.5349 (cls 4.4202, attr 0.1147) - Val Acc: 0.1285
# Epoch [71/80] - Train Loss: 3.2477 (cls 3.1324, attr 0.1153) - Train Acc: 0.2108 - Val Loss: 4.6265 (cls 4.5119, attr 0.1147) - Val Acc: 0.1196
# Epoch [72/80] - Train Loss: 3.2680 (cls 3.1520, attr 0.1159) - Train Acc: 0.2118 - Val Loss: 4.5139 (cls 4.3993, attr 0.1146) - Val Acc: 0.1234
# Epoch [73/80] - Train Loss: 3.2993 (cls 3.1836, attr 0.1157) - Train Acc: 0.2064 - Val Loss: 4.7345 (cls 4.6197, attr 0.1148) - Val Acc: 0.1196
# Epoch [74/80] - Train Loss: 3.1990 (cls 3.0835, attr 0.1155) - Train Acc: 0.2217 - Val Loss: 4.6074 (cls 4.4929, attr 0.1145) - Val Acc: 0.1310
# Epoch [75/80] - Train Loss: 3.1859 (cls 3.0699, attr 0.1159) - Train Acc: 0.2258 - Val Loss: 4.5255 (cls 4.4107, attr 0.1148) - Val Acc: 0.1425
# Epoch [76/80] - Train Loss: 3.1500 (cls 3.0350, attr 0.1150) - Train Acc: 0.2197 - Val Loss: 4.5581 (cls 4.4436, attr 0.1145) - Val Acc: 0.1361
# Epoch [77/80] - Train Loss: 3.1183 (cls 3.0031, attr 0.1152) - Train Acc: 0.2347 - Val Loss: 4.6443 (cls 4.5301, attr 0.1142) - Val Acc: 0.1336
# Epoch [78/80] - Train Loss: 3.0645 (cls 2.9497, attr 0.1148) - Train Acc: 0.2420 - Val Loss: 4.5538 (cls 4.4402, attr 0.1136) - Val Acc: 0.1285
# Epoch [79/80] - Train Loss: 3.1083 (cls 2.9935, attr 0.1148) - Train Acc: 0.2369 - Val Loss: 4.5498 (cls 4.4357, attr 0.1141) - Val Acc: 0.1247
# Epoch [80/80] - Train Loss: 3.1115 (cls 2.9956, attr 0.1159) - Train Acc: 0.2379 - Val Loss: 4.6637 (cls 4.5481, attr 0.1156) - Val Acc: 0.1285
# Best Val Acc: 0.1425

# %%
import matplotlib.pyplot as plt

epochs_range = range(1, epochs + 1)

# Total loss curve
plt.figure(figsize=(8, 5))
plt.plot(epochs_range, train_losses, label="Train Loss")
plt.plot(epochs_range, val_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Total Loss")
plt.title("Train vs Val Total Loss")
plt.legend()
plt.grid(True)
plt.show()

# Class loss curve
plt.figure(figsize=(8, 5))
plt.plot(epochs_range, train_class_losses, label="Train Class Loss")
plt.plot(epochs_range, val_class_losses, label="Val Class Loss")
plt.xlabel("Epoch")
plt.ylabel("Class Loss")
plt.title("Train vs Val Class Loss")
plt.legend()
plt.grid(True)
plt.show()

# Attribute loss curve
plt.figure(figsize=(8, 5))
plt.plot(epochs_range, train_attr_losses, label="Train Attr Loss")
plt.plot(epochs_range, val_attr_losses, label="Val Attr Loss")
plt.xlabel("Epoch")
plt.ylabel("Attribute Loss")
plt.title("Train vs Val Attribute Loss")
plt.legend()
plt.grid(True)
plt.show()

# Accuracy curve
plt.figure(figsize=(8, 5))
plt.plot(epochs_range, train_accs, label="Train Acc")
plt.plot(epochs_range, val_accs, label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Train vs Val Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import zipfile
import os

file_name = "test_images.zip"

with zipfile.ZipFile(file_name, 'r') as zip_ref:
    zip_ref.extractall()

# %%
from tqdm import tqdm

model.load_state_dict(torch.load("best_multitask_model.pth", map_location=device))
model.eval()

# Load test paths
test_df = pd.read_csv("test_images_path.csv")

# Fix path formatting if needed
test_df["image_path"] = test_df["image_path"].str.lstrip("/")
test_df["image_path"] = "test_images/" + test_df["image_path"]

# Use same transform as validation
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

predictions = []

for img_path in tqdm(test_df["image_path"]):
    img = Image.open(img_path).convert("RGB")
    img = val_transform(img)
    img = img.unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(img)
        if isinstance(outputs, tuple):       # Multi-task model
            class_logits, _ = outputs
        else:                                # Single-task model
            class_logits = outputs

        pred = class_logits.argmax(dim=1).item()

    # convert 0-199 back to 1-200 labels
    pred += 1
    predictions.append(pred)

test_df["label"] = predictions

# Keep only required columns in correct order
submission = test_df[["id", "label"]]

# Save final submission
submission.to_csv("submission.csv", index=False)

print("Done! Saved as submission.csv")
submission.head()
# Out:
# 100%|██████████| 4000/4000 [00:24<00:00, 162.48it/s]
# Done! Saved as submission.csv
#    id  label
# 0   1     17
# 1   2    118
# 2   3     28
# 3   4    182
# 4   5     32
